# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
pph_2013 = pd.read_excel('PPH2013.xlsx', sheet_name="POLA KONSUMSI(2013-I)")
pph_2013.head()
# Out:
#    Unnamed: 0  Unnamed: 1                                       Unnamed: 2  \
# 0         NaN         NaN         KANTOR KETAHANAN PANGAN KABUPATEN BANJAR
# 1         NaN         NaN                                 KABUPATEN BANJAR
# 2         NaN         NaN  JL.A.YANI KM 40 GEDUNG BERINTAN LT II MARTAPURA
# 3         NaN         NaN                                              NaN
# 4         NaN         NaN                                              NaN
#
#   Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN        NaN
# 3        NaN        NaN        NaN        NaN        NaN        NaN
# 4        NaN        NaN        NaN        NaN        NaN        NaN
#
#   Unnamed: 9  ... Unnamed: 13 Unnamed: 14 Unnamed: 15  Unnamed: 16  \
# ...

# %%
pph_2013.shape
# Out:
# (1791, 23)

# %%
pph_2013.iloc[6:]
# Out:
#       Unnamed: 0  Unnamed: 1                    Unnamed: 2 Unnamed: 3  \
# 6            NaN         NaN  POLA KONSUMSI PANGAN WILAYAH        NaN
# 7            NaN         NaN                       Wilayah        NaN
# 8            NaN         NaN            Desa Bawahan Pasar        NaN
# 9            NaN         NaN        Desa Mandi Kapau Timur        NaN
# 10           NaN         NaN             Desa Sungai Besar        NaN
# ...          ...         ...                           ...        ...
# 1786         NaN         NaN                           NaN        NaN
# 1787         NaN         NaN                           NaN        NaN
# 1788         NaN         NaN                           NaN        NaN
# 1789         NaN         NaN                           NaN        NaN
# 1790         NaN         NaN                           NaN        NaN
#
#            Unnamed: 4 Unnamed: 5  \
# 6                 NaN        NaN
# 7         Karbohidrat        NaN
# ...

# %%
pph_2013 = pph_2013.iloc[6:]
pph_2013.head()
# Out:
#     Unnamed: 0  Unnamed: 1                    Unnamed: 2 Unnamed: 3  \
# 6          NaN         NaN  POLA KONSUMSI PANGAN WILAYAH        NaN
# 7          NaN         NaN                       Wilayah        NaN
# 8          NaN         NaN            Desa Bawahan Pasar        NaN
# 9          NaN         NaN        Desa Mandi Kapau Timur        NaN
# 10         NaN         NaN             Desa Sungai Besar        NaN
#
#          Unnamed: 4 Unnamed: 5  \
# 6               NaN        NaN
# 7       Karbohidrat        NaN
# 8    Beras, Terigu,        NaN
# 9   Beras, Terigu,         NaN
# 10  Beras, Jagung,         NaN
#
#                                            Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 6                                                 NaN        NaN        NaN
# 7                                      Protein Hewani        NaN        NaN
# 8   Ikan , Daging Ruminansia, Daging Unggas, Telur...        NaN        NaN
# ...

# %%
pph_2013.drop(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 3', 'Unnamed: 5', 'Unnamed: 7', 
               'Unnamed: 8', 'Unnamed: 10', 'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16',
              'Unnamed: 17'], axis=1)
# Out:
#                         Unnamed: 2       Unnamed: 4  \
# 6     POLA KONSUMSI PANGAN WILAYAH              NaN
# 7                          Wilayah      Karbohidrat
# 8               Desa Bawahan Pasar   Beras, Terigu,
# 9           Desa Mandi Kapau Timur  Beras, Terigu,
# 10               Desa Sungai Besar  Beras, Jagung,
# ...                            ...              ...
# 1786                           NaN              NaN
# 1787                           NaN              NaN
# 1788                           NaN              NaN
# 1789                           NaN              NaN
# 1790                           NaN              NaN
#
#                                              Unnamed: 6  \
# 6                                                   NaN
# 7                                        Protein Hewani
# 8     Ikan , Daging Ruminansia, Daging Unggas, Telur...
# 9      Ikan , Daging Ruminansia, Daging Unggas, Telur,
# 10     Ikan , Daging Ruminansia, Daging Unggas, Telur,
# ...
